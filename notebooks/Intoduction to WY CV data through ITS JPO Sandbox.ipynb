# %% [markdown]
# ### The goal of this notebook is to provide a basic example on how to access the USDOT Intelligest Transportation System (ITS) Joint Program Office (JPO) Wyoming Connected Vehcile Pilot data throught the Data Program Sandbox.
#
# Objective of the notebook
# - Show how to access WY pilot data on the sandbox
# - Conduct basic analysis with the data
#
# ----

# %% [markdown]
# ### Load key libraries for the work
# **You will need install these library before running this notebook**
# - boto3: AWS python library (http://boto3.readthedocs.io/en/latest/)
# - pandas: Python Data Analysis Library (http://pandas.pydata.org)

# %%
import boto3
import pandas as pd

# %% [markdown]
# ### Session variable for accessing S3

# %%
session = boto3.Session(profile_name='public')  #note provide is not need
s3 = session.resource('s3')
client = session.client('s3')

# %% [markdown]
# ### List sub folders to determine which dates and times are avaliable

# %%
result =  client.list_objects(Bucket = 'usdot-its-cvpilot-public-data', Delimiter='/', Prefix='wydot/BSM/201708')
for o in result.get('CommonPrefixes'):
        print ('sub folder : ', o.get('Prefix'))
# Out:
# sub folder :  wydot/BSM/20170811T175839Z/
# sub folder :  wydot/BSM/20170814T194035Z/
# sub folder :  wydot/BSM/20170814T194036Z/
# sub folder :  wydot/BSM/20170814T194037Z/
# sub folder :  wydot/BSM/20170814T194038Z/
# sub folder :  wydot/BSM/20170814T194039Z/
# sub folder :  wydot/BSM/20170814T194040Z/
# sub folder :  wydot/BSM/20170814T194041Z/
# sub folder :  wydot/BSM/20170814T194042Z/
# sub folder :  wydot/BSM/20170814T194043Z/
# sub folder :  wydot/BSM/20170814T194044Z/
# sub folder :  wydot/BSM/20170814T194045Z/
# sub folder :  wydot/BSM/20170814T194046Z/
# sub folder :  wydot/BSM/20170814T194047Z/
# sub folder :  wydot/BSM/20170814T194048Z/
# sub folder :  wydot/BSM/20170814T194049Z/
# sub folder :  wydot/BSM/20170814T194050Z/
# sub folder :  wydot/BSM/20170814T194051Z/
# sub folder :  wydot/BSM/20170814T194052Z/
# sub folder :  wydot/BSM/20170814T194053Z/
# sub folder :  wydot/BSM/20170814T194054Z/
# sub folder :  wydot/BSM/20170814T194055Z/
# sub folder :  wydot/BSM/20170814T194056Z/
# sub folder :  wydot/BSM/20170814T194057Z/
# sub folder :  wydot/BSM/20170814T194058Z/
# sub folder :  wydot/BSM/20170814T194059Z/
# sub folder :  wydot/BSM/20170814T194100Z/
# sub folder :  wydot/BSM/20170814T194101Z/
# sub folder :  wydot/BSM/20170814T194102Z/
# sub folder :  wydot/BSM/20170814T194103Z/
# sub folder :  wydot/BSM/20170814T194104Z/
# sub folder :  wydot/BSM/20170814T194105Z/
# sub folder :  wydot/BSM/20170814T194106Z/
# sub folder :  wydot/BSM/20170814T194107Z/
# sub folder :  wydot/BSM/20170814T194108Z/
# sub folder :  wydot/BSM/20170814T194110Z/
# sub folder :  wydot/BSM/20170814T194111Z/
# sub folder :  wydot/BSM/20170814T194112Z/
# sub folder :  wydot/BSM/20170814T194113Z/
# sub folder :  wydot/BSM/20170814T194114Z/
# sub folder :  wydot/BSM/20170814T194115Z/
# sub folder :  wydot/BSM/20170814T194116Z/
# sub folder :  wydot/BSM/20170814T194117Z/
# sub folder :  wydot/BSM/20170814T194118Z/
# sub folder :  wydot/BSM/20170814T194119Z/
# sub folder :  wydot/BSM/20170814T194120Z/
# sub folder :  wydot/BSM/20170814T194121Z/
# sub folder :  wydot/BSM/20170814T194122Z/
# sub folder :  wydot/BSM/20170814T194123Z/
# sub folder :  wydot/BSM/20170814T194124Z/
# sub folder :  wydot/BSM/20170814T194125Z/
# sub folder :  wydot/BSM/20170814T194126Z/
# sub folder :  wydot/BSM/20170814T194127Z/
# sub folder :  wydot/BSM/20170814T194128Z/
# sub folder :  wydot/BSM/20170814T194129Z/
# sub folder :  wydot/BSM/20170814T194130Z/
# sub folder :  wydot/BSM/20170814T194131Z/
# sub folder :  wydot/BSM/20170814T194132Z/
# sub folder :  wydot/BSM/20170814T194133Z/
# sub folder :  wydot/BSM/20170814T194134Z/
# sub folder :  wydot/BSM/20170814T194135Z/
# sub folder :  wydot/BSM/20170814T194136Z/
# sub folder :  wydot/BSM/20170814T194137Z/
# sub folder :  wydot/BSM/20170814T194138Z/
# sub folder :  wydot/BSM/20170814T194139Z/
# sub folder :  wydot/BSM/20170814T194140Z/
# sub folder :  wydot/BSM/20170814T194141Z/
# sub folder :  wydot/BSM/20170814T194142Z/
# sub folder :  wydot/BSM/20170814T194143Z/
# sub folder :  wydot/BSM/20170814T194144Z/
# sub folder :  wydot/BSM/20170814T194145Z/
# sub folder :  wydot/BSM/20170814T194146Z/
# sub folder :  wydot/BSM/20170814T194147Z/
# sub folder :  wydot/BSM/20170814T194148Z/
# sub folder :  wydot/BSM/20170814T194149Z/
# sub folder :  wydot/BSM/20170814T194150Z/
# sub folder :  wydot/BSM/20170814T194151Z/
# sub folder :  wydot/BSM/20170814T194152Z/
# sub folder :  wydot/BSM/20170814T194153Z/
# sub folder :  wydot/BSM/20170814T194155Z/
# sub folder :  wydot/BSM/20170814T194156Z/
# sub folder :  wydot/BSM/20170814T194157Z/
# sub folder :  wydot/BSM/20170814T194158Z/
# sub folder :  wydot/BSM/20170814T194159Z/
# sub folder :  wydot/BSM/20170814T194200Z/
# sub folder :  wydot/BSM/20170814T194201Z/
# sub folder :  wydot/BSM/20170814T194202Z/
# sub folder :  wydot/BSM/20170814T194203Z/
# sub folder :  wydot/BSM/20170814T194204Z/
# sub folder :  wydot/BSM/20170814T194205Z/
# sub folder :  wydot/BSM/20170814T194206Z/
# sub folder :  wydot/BSM/20170814T194207Z/
# sub folder :  wydot/BSM/20170814T194208Z/
# sub folder :  wydot/BSM/20170814T194209Z/
# sub folder :  wydot/BSM/20170814T194210Z/
# sub folder :  wydot/BSM/20170814T194211Z/
# sub folder :  wydot/BSM/20170814T194212Z/
# sub folder :  wydot/BSM/20170814T194216Z/
# sub folder :  wydot/BSM/20170814T194217Z/
# sub folder :  wydot/BSM/20170814T194218Z/
# sub folder :  wydot/BSM/20170814T194219Z/
# sub folder :  wydot/BSM/20170814T194220Z/
# sub folder :  wydot/BSM/20170814T194221Z/
# sub folder :  wydot/BSM/20170814T194222Z/
# sub folder :  wydot/BSM/20170814T194223Z/
# sub folder :  wydot/BSM/20170814T194224Z/
# sub folder :  wydot/BSM/20170814T194225Z/
# sub folder :  wydot/BSM/20170814T194226Z/
# sub folder :  wydot/BSM/20170814T194227Z/
# sub folder :  wydot/BSM/20170814T194228Z/
# sub folder :  wydot/BSM/20170814T194229Z/
# sub folder :  wydot/BSM/20170814T194230Z/
# sub folder :  wydot/BSM/20170814T194231Z/
# sub folder :  wydot/BSM/20170814T194232Z/
# sub folder :  wydot/BSM/20170814T194233Z/
# sub folder :  wydot/BSM/20170814T194234Z/
# sub folder :  wydot/BSM/20170814T194235Z/
# sub folder :  wydot/BSM/20170814T194236Z/
# sub folder :  wydot/BSM/20170814T194237Z/
# sub folder :  wydot/BSM/20170814T194238Z/
# sub folder :  wydot/BSM/20170814T194239Z/
# sub folder :  wydot/BSM/20170814T194240Z/
# sub folder :  wydot/BSM/20170814T194241Z/
# sub folder :  wydot/BSM/20170814T194242Z/
# sub folder :  wydot/BSM/20170814T194243Z/
# sub folder :  wydot/BSM/20170814T194244Z/
# sub folder :  wydot/BSM/20170814T194245Z/
# sub folder :  wydot/BSM/20170814T194246Z/
# sub folder :  wydot/BSM/20170814T194247Z/
# sub folder :  wydot/BSM/20170814T194248Z/
# sub folder :  wydot/BSM/20170814T194249Z/
# sub folder :  wydot/BSM/20170814T194250Z/
# sub folder :  wydot/BSM/20170814T194251Z/
# sub folder :  wydot/BSM/20170814T194252Z/
# sub folder :  wydot/BSM/20170814T194253Z/
# sub folder :  wydot/BSM/20170814T194254Z/
# sub folder :  wydot/BSM/20170814T194255Z/
# sub folder :  wydot/BSM/20170814T194256Z/
# sub folder :  wydot/BSM/20170814T194257Z/
# sub folder :  wydot/BSM/20170814T194258Z/
# sub folder :  wydot/BSM/20170814T194259Z/
# sub folder :  wydot/BSM/20170814T194300Z/
# sub folder :  wydot/BSM/20170814T194301Z/
# sub folder :  wydot/BSM/20170814T194302Z/
# sub folder :  wydot/BSM/20170814T194303Z/
# sub folder :  wydot/BSM/20170814T194304Z/
# sub folder :  wydot/BSM/20170814T194305Z/
# sub folder :  wydot/BSM/20170814T194306Z/
# sub folder :  wydot/BSM/20170814T194307Z/
# sub folder :  wydot/BSM/20170814T194308Z/
# sub folder :  wydot/BSM/20170814T194309Z/
# sub folder :  wydot/BSM/20170814T194310Z/
# sub folder :  wydot/BSM/20170814T194311Z/
# sub folder :  wydot/BSM/20170814T194312Z/
# sub folder :  wydot/BSM/20170814T194313Z/
# sub folder :  wydot/BSM/20170814T194314Z/
# sub folder :  wydot/BSM/20170814T194315Z/
# sub folder :  wydot/BSM/20170814T194316Z/
# sub folder :  wydot/BSM/20170814T194317Z/
# sub folder :  wydot/BSM/20170814T194318Z/
# sub folder :  wydot/BSM/20170814T194319Z/
# sub folder :  wydot/BSM/20170814T194320Z/
# sub folder :  wydot/BSM/20170814T194321Z/
# sub folder :  wydot/BSM/20170814T194322Z/
# sub folder :  wydot/BSM/20170814T194323Z/
# sub folder :  wydot/BSM/20170814T194324Z/
# sub folder :  wydot/BSM/20170814T194325Z/
# sub folder :  wydot/BSM/20170814T194326Z/
# sub folder :  wydot/BSM/20170814T194327Z/
# sub folder :  wydot/BSM/20170814T194328Z/
# sub folder :  wydot/BSM/20170814T194329Z/
# sub folder :  wydot/BSM/20170814T194330Z/
# sub folder :  wydot/BSM/20170814T194331Z/
# sub folder :  wydot/BSM/20170814T194332Z/
# sub folder :  wydot/BSM/20170814T194333Z/
# sub folder :  wydot/BSM/20170814T194334Z/
# sub folder :  wydot/BSM/20170814T194335Z/
# sub folder :  wydot/BSM/20170814T194336Z/
# sub folder :  wydot/BSM/20170814T194337Z/
# sub folder :  wydot/BSM/20170814T194338Z/
# sub folder :  wydot/BSM/20170814T194339Z/
# sub folder :  wydot/BSM/20170814T194340Z/
# sub folder :  wydot/BSM/20170814T194341Z/
# sub folder :  wydot/BSM/20170814T194342Z/
# sub folder :  wydot/BSM/20170814T194343Z/
# sub folder :  wydot/BSM/20170814T194344Z/
# sub folder :  wydot/BSM/20170814T194345Z/
# sub folder :  wydot/BSM/20170814T194346Z/
# sub folder :  wydot/BSM/20170814T194347Z/
# sub folder :  wydot/BSM/20170814T194348Z/
# sub folder :  wydot/BSM/20170814T194349Z/
# sub folder :  wydot/BSM/20170814T194350Z/
# sub folder :  wydot/BSM/20170814T194351Z/
# sub folder :  wydot/BSM/20170814T194352Z/
# sub folder :  wydot/BSM/20170814T194353Z/
# sub folder :  wydot/BSM/20170814T194354Z/
# sub folder :  wydot/BSM/20170814T194355Z/
# sub folder :  wydot/BSM/20170814T194356Z/
# sub folder :  wydot/BSM/20170814T194357Z/
# sub folder :  wydot/BSM/20170814T194358Z/
# sub folder :  wydot/BSM/20170814T194359Z/
# sub folder :  wydot/BSM/20170814T194400Z/
# sub folder :  wydot/BSM/20170814T194401Z/
# sub folder :  wydot/BSM/20170814T194402Z/
# sub folder :  wydot/BSM/20170814T194403Z/
# sub folder :  wydot/BSM/20170814T194404Z/
# sub folder :  wydot/BSM/20170814T194405Z/
# sub folder :  wydot/BSM/20170814T194406Z/
# sub folder :  wydot/BSM/20170814T194407Z/
# sub folder :  wydot/BSM/20170814T194408Z/
# sub folder :  wydot/BSM/20170814T194409Z/
# sub folder :  wydot/BSM/20170814T194410Z/
# sub folder :  wydot/BSM/20170814T194411Z/
# sub folder :  wydot/BSM/20170814T194412Z/
# sub folder :  wydot/BSM/20170814T194413Z/
# sub folder :  wydot/BSM/20170814T194414Z/
# sub folder :  wydot/BSM/20170814T194415Z/
# sub folder :  wydot/BSM/20170814T194416Z/
# sub folder :  wydot/BSM/20170814T194417Z/
# sub folder :  wydot/BSM/20170814T194418Z/
# sub folder :  wydot/BSM/20170814T194419Z/
# sub folder :  wydot/BSM/20170814T194420Z/
# sub folder :  wydot/BSM/20170814T194421Z/
# sub folder :  wydot/BSM/20170814T194422Z/
# sub folder :  wydot/BSM/20170814T194423Z/
# sub folder :  wydot/BSM/20170814T194424Z/
# sub folder :  wydot/BSM/20170814T194425Z/
# sub folder :  wydot/BSM/20170814T194426Z/
# sub folder :  wydot/BSM/20170814T194427Z/
# sub folder :  wydot/BSM/20170814T194428Z/
# sub folder :  wydot/BSM/20170814T194429Z/
# sub folder :  wydot/BSM/20170814T194430Z/
# sub folder :  wydot/BSM/20170814T194431Z/
# sub folder :  wydot/BSM/20170814T194432Z/
# sub folder :  wydot/BSM/20170814T194433Z/
# sub folder :  wydot/BSM/20170814T194434Z/
# sub folder :  wydot/BSM/20170814T194435Z/
# sub folder :  wydot/BSM/20170814T194436Z/
# sub folder :  wydot/BSM/20170814T194437Z/
# sub folder :  wydot/BSM/20170814T194438Z/
# sub folder :  wydot/BSM/20170814T194439Z/
# sub folder :  wydot/BSM/20170814T194440Z/
# sub folder :  wydot/BSM/20170814T194441Z/
# sub folder :  wydot/BSM/20170814T194442Z/
# sub folder :  wydot/BSM/20170814T194443Z/
# sub folder :  wydot/BSM/20170814T194444Z/
# sub folder :  wydot/BSM/20170814T194445Z/
# sub folder :  wydot/BSM/20170814T194446Z/
# sub folder :  wydot/BSM/20170814T194447Z/
# sub folder :  wydot/BSM/20170814T194448Z/
# sub folder :  wydot/BSM/20170814T194449Z/
# sub folder :  wydot/BSM/20170814T194450Z/
# sub folder :  wydot/BSM/20170814T194451Z/
# sub folder :  wydot/BSM/20170814T194452Z/
# sub folder :  wydot/BSM/20170814T194453Z/
# sub folder :  wydot/BSM/20170814T194454Z/
# sub folder :  wydot/BSM/20170814T194455Z/
# sub folder :  wydot/BSM/20170814T194456Z/
# sub folder :  wydot/BSM/20170814T194457Z/
# sub folder :  wydot/BSM/20170814T194458Z/
# sub folder :  wydot/BSM/20170814T194459Z/
# sub folder :  wydot/BSM/20170814T194500Z/
# sub folder :  wydot/BSM/20170814T194501Z/
# sub folder :  wydot/BSM/20170814T194502Z/
# sub folder :  wydot/BSM/20170814T194503Z/
# sub folder :  wydot/BSM/20170814T194504Z/
# sub folder :  wydot/BSM/20170814T194505Z/
# sub folder :  wydot/BSM/20170814T194506Z/
# sub folder :  wydot/BSM/20170814T194507Z/
# sub folder :  wydot/BSM/20170814T194508Z/
# sub folder :  wydot/BSM/20170814T194509Z/
# sub folder :  wydot/BSM/20170814T194510Z/
# sub folder :  wydot/BSM/20170814T194511Z/
# sub folder :  wydot/BSM/20170814T194512Z/
# sub folder :  wydot/BSM/20170814T194513Z/
# sub folder :  wydot/BSM/20170814T194514Z/
# sub folder :  wydot/BSM/20170814T194515Z/
# sub folder :  wydot/BSM/20170814T194516Z/
# sub folder :  wydot/BSM/20170814T194517Z/
# sub folder :  wydot/BSM/20170814T194518Z/
# sub folder :  wydot/BSM/20170814T194519Z/
# sub folder :  wydot/BSM/20170814T194520Z/
# sub folder :  wydot/BSM/20170814T194521Z/
# sub folder :  wydot/BSM/20170814T194522Z/
# sub folder :  wydot/BSM/20170814T194523Z/
# sub folder :  wydot/BSM/20170814T194524Z/
# sub folder :  wydot/BSM/20170814T194525Z/
# sub folder :  wydot/BSM/20170814T194526Z/
# sub folder :  wydot/BSM/20170814T194527Z/
# sub folder :  wydot/BSM/20170814T194528Z/
# sub folder :  wydot/BSM/20170814T194529Z/
# sub folder :  wydot/BSM/20170814T194530Z/
# sub folder :  wydot/BSM/20170814T194531Z/
# sub folder :  wydot/BSM/20170814T194532Z/
# sub folder :  wydot/BSM/20170814T194533Z/
# sub folder :  wydot/BSM/20170814T194534Z/
# sub folder :  wydot/BSM/20170814T194535Z/
# sub folder :  wydot/BSM/20170814T194536Z/
# sub folder :  wydot/BSM/20170814T194537Z/
# sub folder :  wydot/BSM/20170814T194539Z/
# sub folder :  wydot/BSM/20170814T194540Z/
# sub folder :  wydot/BSM/20170814T194541Z/
# sub folder :  wydot/BSM/20170814T194542Z/
# sub folder :  wydot/BSM/20170814T194543Z/
# sub folder :  wydot/BSM/20170814T194544Z/
# sub folder :  wydot/BSM/20170814T194545Z/
# sub folder :  wydot/BSM/20170814T194546Z/
# sub folder :  wydot/BSM/20170814T194547Z/
# sub folder :  wydot/BSM/20170814T194548Z/
# sub folder :  wydot/BSM/20170814T194549Z/
# sub folder :  wydot/BSM/20170814T194550Z/
# sub folder :  wydot/BSM/20170814T194551Z/
# sub folder :  wydot/BSM/20170814T194552Z/
# sub folder :  wydot/BSM/20170814T194553Z/
# sub folder :  wydot/BSM/20170814T194554Z/
# sub folder :  wydot/BSM/20170814T194555Z/
# sub folder :  wydot/BSM/20170814T194556Z/
# sub folder :  wydot/BSM/20170814T194557Z/
# sub folder :  wydot/BSM/20170814T194558Z/
# sub folder :  wydot/BSM/20170814T194559Z/
# sub folder :  wydot/BSM/20170814T194600Z/
# sub folder :  wydot/BSM/20170814T194601Z/
# sub folder :  wydot/BSM/20170814T194602Z/
# sub folder :  wydot/BSM/20170814T194603Z/
# sub folder :  wydot/BSM/20170814T194604Z/
# sub folder :  wydot/BSM/20170814T194605Z/
# sub folder :  wydot/BSM/20170814T194606Z/
# sub folder :  wydot/BSM/20170814T194607Z/
# sub folder :  wydot/BSM/20170814T194608Z/
# sub folder :  wydot/BSM/20170814T194609Z/
# sub folder :  wydot/BSM/20170814T194610Z/
# sub folder :  wydot/BSM/20170814T194611Z/
# sub folder :  wydot/BSM/20170814T194612Z/
# sub folder :  wydot/BSM/20170814T194613Z/
# sub folder :  wydot/BSM/20170814T194615Z/
# sub folder :  wydot/BSM/20170814T194616Z/
# sub folder :  wydot/BSM/20170814T194617Z/
# sub folder :  wydot/BSM/20170814T194618Z/
# sub folder :  wydot/BSM/20170814T194619Z/
# sub folder :  wydot/BSM/20170814T194620Z/
# sub folder :  wydot/BSM/20170814T194621Z/
# sub folder :  wydot/BSM/20170814T194622Z/
# sub folder :  wydot/BSM/20170814T194623Z/
# sub folder :  wydot/BSM/20170814T194624Z/
# sub folder :  wydot/BSM/20170814T194625Z/
# sub folder :  wydot/BSM/20170814T194627Z/
# sub folder :  wydot/BSM/20170814T194628Z/
# sub folder :  wydot/BSM/20170814T194629Z/
# sub folder :  wydot/BSM/20170814T194630Z/
# sub folder :  wydot/BSM/20170814T194631Z/
# sub folder :  wydot/BSM/20170814T194632Z/
# sub folder :  wydot/BSM/20170814T194633Z/
# sub folder :  wydot/BSM/20170814T194634Z/
# sub folder :  wydot/BSM/20170814T194635Z/
# sub folder :  wydot/BSM/20170814T194636Z/
# sub folder :  wydot/BSM/20170814T194637Z/
# sub folder :  wydot/BSM/20170814T194638Z/
# sub folder :  wydot/BSM/20170814T194640Z/
# sub folder :  wydot/BSM/20170814T194641Z/
# sub folder :  wydot/BSM/20170814T194642Z/
# sub folder :  wydot/BSM/20170814T194643Z/
# sub folder :  wydot/BSM/20170814T194644Z/
# sub folder :  wydot/BSM/20170814T194645Z/
# sub folder :  wydot/BSM/20170814T194646Z/
# sub folder :  wydot/BSM/20170814T194647Z/
# sub folder :  wydot/BSM/20170814T194648Z/
# sub folder :  wydot/BSM/20170814T194649Z/
# sub folder :  wydot/BSM/20170814T194650Z/
# sub folder :  wydot/BSM/20170814T194651Z/
# sub folder :  wydot/BSM/20170814T194652Z/
# sub folder :  wydot/BSM/20170814T194653Z/
# sub folder :  wydot/BSM/20170814T194654Z/
# sub folder :  wydot/BSM/20170814T194655Z/
# sub folder :  wydot/BSM/20170814T194656Z/
# sub folder :  wydot/BSM/20170814T194657Z/
# sub folder :  wydot/BSM/20170814T194658Z/
# sub folder :  wydot/BSM/20170814T194659Z/
# sub folder :  wydot/BSM/20170814T194700Z/
# sub folder :  wydot/BSM/20170814T194701Z/
# sub folder :  wydot/BSM/20170814T194702Z/
# sub folder :  wydot/BSM/20170814T194703Z/
# sub folder :  wydot/BSM/20170814T194704Z/
# sub folder :  wydot/BSM/20170814T194705Z/
# sub folder :  wydot/BSM/20170814T194706Z/
# sub folder :  wydot/BSM/20170814T194707Z/
# sub folder :  wydot/BSM/20170814T194708Z/
# sub folder :  wydot/BSM/20170814T194709Z/
# sub folder :  wydot/BSM/20170814T194710Z/
# sub folder :  wydot/BSM/20170814T194711Z/
# sub folder :  wydot/BSM/20170814T194712Z/
# sub folder :  wydot/BSM/20170814T194713Z/
# sub folder :  wydot/BSM/20170814T194714Z/
# sub folder :  wydot/BSM/20170814T194715Z/
# sub folder :  wydot/BSM/20170814T194716Z/
# sub folder :  wydot/BSM/20170814T194717Z/
# sub folder :  wydot/BSM/20170814T194718Z/
# sub folder :  wydot/BSM/20170814T194719Z/
# sub folder :  wydot/BSM/20170814T194720Z/
# sub folder :  wydot/BSM/20170814T194721Z/
# sub folder :  wydot/BSM/20170814T194722Z/
# sub folder :  wydot/BSM/20170814T194723Z/
# sub folder :  wydot/BSM/20170814T194724Z/
# sub folder :  wydot/BSM/20170814T194725Z/
# sub folder :  wydot/BSM/20170814T194726Z/
# sub folder :  wydot/BSM/20170814T194727Z/
# sub folder :  wydot/BSM/20170814T194728Z/
# sub folder :  wydot/BSM/20170814T194729Z/
# sub folder :  wydot/BSM/20170814T194730Z/
# sub folder :  wydot/BSM/20170814T194731Z/
# sub folder :  wydot/BSM/20170814T194732Z/
# sub folder :  wydot/BSM/20170814T194733Z/
# sub folder :  wydot/BSM/20170814T194734Z/
# sub folder :  wydot/BSM/20170814T194735Z/
# sub folder :  wydot/BSM/20170814T194736Z/
# sub folder :  wydot/BSM/20170814T194737Z/
# sub folder :  wydot/BSM/20170814T194738Z/
# sub folder :  wydot/BSM/20170814T194739Z/
# sub folder :  wydot/BSM/20170814T194740Z/
# sub folder :  wydot/BSM/20170814T194741Z/
# sub folder :  wydot/BSM/20170814T194742Z/
# sub folder :  wydot/BSM/20170814T194743Z/
# sub folder :  wydot/BSM/20170814T194744Z/
# sub folder :  wydot/BSM/20170814T194745Z/
# sub folder :  wydot/BSM/20170814T194746Z/
# sub folder :  wydot/BSM/20170814T194747Z/
# sub folder :  wydot/BSM/20170814T194748Z/
# sub folder :  wydot/BSM/20170814T194749Z/
# sub folder :  wydot/BSM/20170814T194750Z/
# sub folder :  wydot/BSM/20170814T194751Z/
# sub folder :  wydot/BSM/20170814T194752Z/
# sub folder :  wydot/BSM/20170814T194753Z/
# sub folder :  wydot/BSM/20170814T194754Z/
# sub folder :  wydot/BSM/20170814T194755Z/
# sub folder :  wydot/BSM/20170814T194756Z/
# sub folder :  wydot/BSM/20170814T194757Z/
# sub folder :  wydot/BSM/20170814T194758Z/
# sub folder :  wydot/BSM/20170814T194759Z/
# sub folder :  wydot/BSM/20170814T194800Z/
# sub folder :  wydot/BSM/20170814T194801Z/
# sub folder :  wydot/BSM/20170814T194802Z/
# sub folder :  wydot/BSM/20170814T194803Z/
# sub folder :  wydot/BSM/20170814T194804Z/
# sub folder :  wydot/BSM/20170814T194805Z/
# sub folder :  wydot/BSM/20170814T194806Z/
# sub folder :  wydot/BSM/20170814T194807Z/
# sub folder :  wydot/BSM/20170814T194808Z/
# sub folder :  wydot/BSM/20170814T194809Z/
# sub folder :  wydot/BSM/20170814T194810Z/
# sub folder :  wydot/BSM/20170814T194811Z/
# sub folder :  wydot/BSM/20170814T194812Z/
# sub folder :  wydot/BSM/20170814T194813Z/
# sub folder :  wydot/BSM/20170814T194814Z/
# sub folder :  wydot/BSM/20170814T194815Z/
# sub folder :  wydot/BSM/20170814T194816Z/
# sub folder :  wydot/BSM/20170814T194817Z/
# sub folder :  wydot/BSM/20170814T194818Z/
# sub folder :  wydot/BSM/20170814T194819Z/
# sub folder :  wydot/BSM/20170814T194820Z/
# sub folder :  wydot/BSM/20170814T194821Z/
# sub folder :  wydot/BSM/20170814T194822Z/
# sub folder :  wydot/BSM/20170814T194823Z/
# sub folder :  wydot/BSM/20170814T194824Z/
# sub folder :  wydot/BSM/20170814T194825Z/
# sub folder :  wydot/BSM/20170814T194826Z/
# sub folder :  wydot/BSM/20170814T194827Z/
# sub folder :  wydot/BSM/20170814T194828Z/
# sub folder :  wydot/BSM/20170814T194829Z/
# sub folder :  wydot/BSM/20170814T194830Z/
# sub folder :  wydot/BSM/20170814T194831Z/
# sub folder :  wydot/BSM/20170814T194832Z/
# sub folder :  wydot/BSM/20170814T194833Z/
# sub folder :  wydot/BSM/20170814T194834Z/
# sub folder :  wydot/BSM/20170814T194835Z/
# sub folder :  wydot/BSM/20170814T194836Z/
# sub folder :  wydot/BSM/20170814T194837Z/
# sub folder :  wydot/BSM/20170814T194838Z/
# sub folder :  wydot/BSM/20170814T194839Z/
# sub folder :  wydot/BSM/20170814T194840Z/
# sub folder :  wydot/BSM/20170814T194841Z/
# sub folder :  wydot/BSM/20170814T194842Z/
# sub folder :  wydot/BSM/20170814T194843Z/
# sub folder :  wydot/BSM/20170814T194844Z/
# sub folder :  wydot/BSM/20170814T194845Z/
# sub folder :  wydot/BSM/20170814T194846Z/
# sub folder :  wydot/BSM/20170814T194847Z/
# sub folder :  wydot/BSM/20170814T194848Z/
# sub folder :  wydot/BSM/20170814T194849Z/
# sub folder :  wydot/BSM/20170814T194850Z/
# sub folder :  wydot/BSM/20170814T194851Z/
# sub folder :  wydot/BSM/20170814T194852Z/
# sub folder :  wydot/BSM/20170814T194853Z/
# sub folder :  wydot/BSM/20170814T194854Z/
# sub folder :  wydot/BSM/20170814T194855Z/
# sub folder :  wydot/BSM/20170814T194856Z/
# sub folder :  wydot/BSM/20170814T194857Z/
# sub folder :  wydot/BSM/20170814T194858Z/
# sub folder :  wydot/BSM/20170814T194859Z/
# sub folder :  wydot/BSM/20170814T194900Z/
# sub folder :  wydot/BSM/20170814T194901Z/
# sub folder :  wydot/BSM/20170814T194902Z/
# sub folder :  wydot/BSM/20170814T194903Z/
# sub folder :  wydot/BSM/20170814T194904Z/
# sub folder :  wydot/BSM/20170814T194905Z/
# sub folder :  wydot/BSM/20170814T194906Z/
# sub folder :  wydot/BSM/20170814T194907Z/
# sub folder :  wydot/BSM/20170814T194908Z/
# sub folder :  wydot/BSM/20170814T194909Z/
# sub folder :  wydot/BSM/20170814T194910Z/
# sub folder :  wydot/BSM/20170814T194911Z/
# sub folder :  wydot/BSM/20170814T194912Z/
# sub folder :  wydot/BSM/20170814T194913Z/
# sub folder :  wydot/BSM/20170814T194914Z/
# sub folder :  wydot/BSM/20170814T194915Z/
# sub folder :  wydot/BSM/20170814T194916Z/
# sub folder :  wydot/BSM/20170814T194917Z/
# sub folder :  wydot/BSM/20170814T194918Z/
# sub folder :  wydot/BSM/20170814T194919Z/
# sub folder :  wydot/BSM/20170814T194920Z/
# sub folder :  wydot/BSM/20170814T194921Z/
# sub folder :  wydot/BSM/20170814T194922Z/
# sub folder :  wydot/BSM/20170814T194923Z/
# sub folder :  wydot/BSM/20170814T194924Z/
# sub folder :  wydot/BSM/20170814T194925Z/
# sub folder :  wydot/BSM/20170814T194926Z/
# sub folder :  wydot/BSM/20170814T194927Z/
# sub folder :  wydot/BSM/20170814T194928Z/
# sub folder :  wydot/BSM/20170814T194929Z/
# sub folder :  wydot/BSM/20170814T194930Z/
# sub folder :  wydot/BSM/20170814T194931Z/
# sub folder :  wydot/BSM/20170814T194932Z/
# sub folder :  wydot/BSM/20170814T194933Z/
# sub folder :  wydot/BSM/20170814T194934Z/
# sub folder :  wydot/BSM/20170814T194935Z/
# sub folder :  wydot/BSM/20170814T194936Z/
# sub folder :  wydot/BSM/20170814T194937Z/
# sub folder :  wydot/BSM/20170814T194938Z/
# sub folder :  wydot/BSM/20170814T194939Z/
# sub folder :  wydot/BSM/20170814T194940Z/
# sub folder :  wydot/BSM/20170814T194941Z/
# sub folder :  wydot/BSM/20170814T194942Z/
# sub folder :  wydot/BSM/20170814T194943Z/
# sub folder :  wydot/BSM/20170814T194944Z/
# sub folder :  wydot/BSM/20170814T194945Z/
# sub folder :  wydot/BSM/20170814T194946Z/
# sub folder :  wydot/BSM/20170814T194947Z/
# sub folder :  wydot/BSM/20170814T194948Z/
# sub folder :  wydot/BSM/20170814T194949Z/
# sub folder :  wydot/BSM/20170814T194950Z/
# sub folder :  wydot/BSM/20170814T194951Z/
# sub folder :  wydot/BSM/20170814T194952Z/
# sub folder :  wydot/BSM/20170814T194953Z/
# sub folder :  wydot/BSM/20170814T194954Z/
# sub folder :  wydot/BSM/20170814T194955Z/
# sub folder :  wydot/BSM/20170814T194956Z/
# sub folder :  wydot/BSM/20170814T194957Z/
# sub folder :  wydot/BSM/20170814T194958Z/
# sub folder :  wydot/BSM/20170814T194959Z/
# sub folder :  wydot/BSM/20170814T195000Z/
# sub folder :  wydot/BSM/20170814T195001Z/
# sub folder :  wydot/BSM/20170814T195002Z/
# sub folder :  wydot/BSM/20170814T195003Z/
# sub folder :  wydot/BSM/20170814T195004Z/
# sub folder :  wydot/BSM/20170814T195005Z/
# sub folder :  wydot/BSM/20170814T195006Z/
# sub folder :  wydot/BSM/20170814T195007Z/
# sub folder :  wydot/BSM/20170814T195008Z/
# sub folder :  wydot/BSM/20170814T195009Z/
# sub folder :  wydot/BSM/20170814T195010Z/
# sub folder :  wydot/BSM/20170814T195011Z/
# sub folder :  wydot/BSM/20170814T195012Z/
# sub folder :  wydot/BSM/20170814T195013Z/
# sub folder :  wydot/BSM/20170814T195014Z/
# sub folder :  wydot/BSM/20170814T195015Z/
# sub folder :  wydot/BSM/20170814T195016Z/
# sub folder :  wydot/BSM/20170814T195017Z/
# sub folder :  wydot/BSM/20170814T195018Z/
# sub folder :  wydot/BSM/20170814T195019Z/
# sub folder :  wydot/BSM/20170814T195020Z/
# sub folder :  wydot/BSM/20170814T195021Z/
# sub folder :  wydot/BSM/20170814T195022Z/
# sub folder :  wydot/BSM/20170814T195023Z/
# sub folder :  wydot/BSM/20170814T195024Z/
# sub folder :  wydot/BSM/20170814T195025Z/
# sub folder :  wydot/BSM/20170814T195026Z/
# sub folder :  wydot/BSM/20170814T195027Z/
# sub folder :  wydot/BSM/20170814T195028Z/
# sub folder :  wydot/BSM/20170814T195029Z/
# sub folder :  wydot/BSM/20170814T195030Z/
# sub folder :  wydot/BSM/20170814T195031Z/
# sub folder :  wydot/BSM/20170814T195032Z/
# sub folder :  wydot/BSM/20170814T195033Z/
# sub folder :  wydot/BSM/20170814T195034Z/
# sub folder :  wydot/BSM/20170814T195035Z/
# sub folder :  wydot/BSM/20170814T195036Z/
# sub folder :  wydot/BSM/20170814T195037Z/
# sub folder :  wydot/BSM/20170814T195038Z/
# sub folder :  wydot/BSM/20170814T195039Z/
# sub folder :  wydot/BSM/20170814T195040Z/
# sub folder :  wydot/BSM/20170814T195041Z/
# sub folder :  wydot/BSM/20170814T195042Z/
# sub folder :  wydot/BSM/20170814T195043Z/
# sub folder :  wydot/BSM/20170814T195044Z/
# sub folder :  wydot/BSM/20170814T195045Z/
# sub folder :  wydot/BSM/20170814T195046Z/
# sub folder :  wydot/BSM/20170814T195047Z/
# sub folder :  wydot/BSM/20170814T195048Z/
# sub folder :  wydot/BSM/20170814T195049Z/
# sub folder :  wydot/BSM/20170814T195050Z/
# sub folder :  wydot/BSM/20170814T195051Z/
# sub folder :  wydot/BSM/20170814T195052Z/
# sub folder :  wydot/BSM/20170814T195053Z/
# sub folder :  wydot/BSM/20170814T195054Z/
# sub folder :  wydot/BSM/20170814T195055Z/
# sub folder :  wydot/BSM/20170814T195056Z/
# sub folder :  wydot/BSM/20170814T195057Z/
# sub folder :  wydot/BSM/20170814T195058Z/
# sub folder :  wydot/BSM/20170814T195059Z/
# sub folder :  wydot/BSM/20170814T195100Z/
# sub folder :  wydot/BSM/20170814T195104Z/
# sub folder :  wydot/BSM/20170814T195105Z/
# sub folder :  wydot/BSM/20170814T195106Z/
# sub folder :  wydot/BSM/20170814T195107Z/
# sub folder :  wydot/BSM/20170814T195108Z/
# sub folder :  wydot/BSM/20170814T195109Z/
# sub folder :  wydot/BSM/20170814T195110Z/
# sub folder :  wydot/BSM/20170814T195111Z/
# sub folder :  wydot/BSM/20170814T195112Z/
# sub folder :  wydot/BSM/20170814T195113Z/
# sub folder :  wydot/BSM/20170814T195114Z/
# sub folder :  wydot/BSM/20170814T195115Z/
# sub folder :  wydot/BSM/20170814T195116Z/
# sub folder :  wydot/BSM/20170814T195117Z/
# sub folder :  wydot/BSM/20170814T195118Z/
# sub folder :  wydot/BSM/20170814T195119Z/
# sub folder :  wydot/BSM/20170814T195120Z/
# sub folder :  wydot/BSM/20170814T195121Z/
# sub folder :  wydot/BSM/20170814T195122Z/
# sub folder :  wydot/BSM/20170814T195123Z/
# sub folder :  wydot/BSM/20170814T195124Z/
# sub folder :  wydot/BSM/20170814T195125Z/
# sub folder :  wydot/BSM/20170814T195126Z/
# sub folder :  wydot/BSM/20170814T195127Z/
# sub folder :  wydot/BSM/20170814T195128Z/
# sub folder :  wydot/BSM/20170814T195129Z/
# sub folder :  wydot/BSM/20170814T195130Z/
# sub folder :  wydot/BSM/20170814T195131Z/
# sub folder :  wydot/BSM/20170814T195132Z/
# sub folder :  wydot/BSM/20170814T195133Z/
# sub folder :  wydot/BSM/20170814T195134Z/
# sub folder :  wydot/BSM/20170814T195135Z/
# sub folder :  wydot/BSM/20170814T195136Z/
# sub folder :  wydot/BSM/20170814T195137Z/
# sub folder :  wydot/BSM/20170814T195138Z/
# sub folder :  wydot/BSM/20170815T234600645Z/
# sub folder :  wydot/BSM/20170815T234600656Z/
# sub folder :  wydot/BSM/20170815T234600667Z/
# sub folder :  wydot/BSM/20170815T234600674Z/
# sub folder :  wydot/BSM/20170815T23460069Z/
# sub folder :  wydot/BSM/20170815T234600715Z/
# sub folder :  wydot/BSM/20170815T234600722Z/
# sub folder :  wydot/BSM/20170815T234600734Z/
# sub folder :  wydot/BSM/20170815T234600753Z/
# sub folder :  wydot/BSM/20170815T234600761Z/
# sub folder :  wydot/BSM/20170815T234600769Z/
# sub folder :  wydot/BSM/20170815T234600783Z/
# sub folder :  wydot/BSM/20170815T234600861Z/
# sub folder :  wydot/BSM/20170815T2346008Z/
# sub folder :  wydot/BSM/20170815T234600902Z/
# sub folder :  wydot/BSM/20170815T234600914Z/
# sub folder :  wydot/BSM/20170815T234600962Z/
# sub folder :  wydot/BSM/20170815T234601048Z/
# sub folder :  wydot/BSM/20170815T234601086Z/
# sub folder :  wydot/BSM/20170815T234601091Z/
# sub folder :  wydot/BSM/20170815T234601101Z/
# sub folder :  wydot/BSM/20170815T234601114Z/
# sub folder :  wydot/BSM/20170815T234601125Z/
# sub folder :  wydot/BSM/20170815T234601131Z/
# sub folder :  wydot/BSM/20170815T234601149Z/
# sub folder :  wydot/BSM/20170815T234601165Z/
# sub folder :  wydot/BSM/20170815T234601173Z/
# sub folder :  wydot/BSM/20170815T234601189Z/
# sub folder :  wydot/BSM/20170815T234601195Z/
# sub folder :  wydot/BSM/20170815T234601201Z/
# sub folder :  wydot/BSM/20170815T234601205Z/
# sub folder :  wydot/BSM/20170815T234601208Z/
# sub folder :  wydot/BSM/20170815T234601226Z/
# sub folder :  wydot/BSM/20170815T234601228Z/
# sub folder :  wydot/BSM/20170815T234601251Z/
# sub folder :  wydot/BSM/20170815T234601278Z/
# sub folder :  wydot/BSM/20170815T234601291Z/
# sub folder :  wydot/BSM/20170815T234601337Z/
# sub folder :  wydot/BSM/20170815T234601414Z/
# sub folder :  wydot/BSM/20170815T234601444Z/
# sub folder :  wydot/BSM/20170815T234601463Z/
# sub folder :  wydot/BSM/20170815T234601483Z/
# sub folder :  wydot/BSM/20170815T234601487Z/
# sub folder :  wydot/BSM/20170815T234601492Z/
# sub folder :  wydot/BSM/20170815T234601497Z/
# sub folder :  wydot/BSM/20170815T234601515Z/
# sub folder :  wydot/BSM/20170815T234601526Z/
# sub folder :  wydot/BSM/20170815T234601533Z/
# sub folder :  wydot/BSM/20170815T234601535Z/
# sub folder :  wydot/BSM/20170815T234601545Z/
# sub folder :  wydot/BSM/20170815T23460155Z/
# sub folder :  wydot/BSM/20170815T234601565Z/
# sub folder :  wydot/BSM/20170815T23460156Z/
# sub folder :  wydot/BSM/20170815T234601577Z/
# sub folder :  wydot/BSM/20170815T234601585Z/
# sub folder :  wydot/BSM/20170815T23460159Z/
# sub folder :  wydot/BSM/20170815T234601604Z/
# sub folder :  wydot/BSM/20170815T234601606Z/
# sub folder :  wydot/BSM/20170815T23460161Z/
# sub folder :  wydot/BSM/20170815T234601623Z/
# sub folder :  wydot/BSM/20170815T234601627Z/
# sub folder :  wydot/BSM/20170815T23460162Z/
# sub folder :  wydot/BSM/20170815T234601634Z/
# sub folder :  wydot/BSM/20170815T234601658Z/
# sub folder :  wydot/BSM/20170815T234601666Z/
# sub folder :  wydot/BSM/20170815T234601683Z/
# sub folder :  wydot/BSM/20170815T23460168Z/
# sub folder :  wydot/BSM/20170815T234601692Z/
# sub folder :  wydot/BSM/20170815T23460169Z/
# sub folder :  wydot/BSM/20170815T234601701Z/
# sub folder :  wydot/BSM/20170815T234601717Z/
# sub folder :  wydot/BSM/20170815T23460171Z/
# sub folder :  wydot/BSM/20170815T234601723Z/
# sub folder :  wydot/BSM/20170815T234601753Z/
# sub folder :  wydot/BSM/20170815T234601756Z/
# sub folder :  wydot/BSM/20170815T234601761Z/
# sub folder :  wydot/BSM/20170815T234601807Z/
# sub folder :  wydot/BSM/20170815T234601812Z/
# sub folder :  wydot/BSM/20170815T234601817Z/
# sub folder :  wydot/BSM/20170815T234601821Z/
# sub folder :  wydot/BSM/20170815T234601825Z/
# sub folder :  wydot/BSM/20170815T234601833Z/
# sub folder :  wydot/BSM/20170815T234601846Z/
# sub folder :  wydot/BSM/20170815T23460184Z/
# sub folder :  wydot/BSM/20170815T234601852Z/
# sub folder :  wydot/BSM/20170815T234601867Z/
# sub folder :  wydot/BSM/20170815T23460186Z/
# sub folder :  wydot/BSM/20170815T234601876Z/
# sub folder :  wydot/BSM/20170815T234601888Z/
# sub folder :  wydot/BSM/20170815T234601894Z/
# sub folder :  wydot/BSM/20170815T23460189Z/
# sub folder :  wydot/BSM/20170815T234601911Z/
# sub folder :  wydot/BSM/20170815T234601922Z/
# sub folder :  wydot/BSM/20170815T234601924Z/
# sub folder :  wydot/BSM/20170815T234601936Z/
# sub folder :  wydot/BSM/20170815T23460196Z/
# sub folder :  wydot/BSM/20170815T23460198Z/
# sub folder :  wydot/BSM/20170815T234601991Z/
# sub folder :  wydot/BSM/20170815T234602039Z/
# sub folder :  wydot/BSM/20170815T234602042Z/
# sub folder :  wydot/BSM/20170815T234602056Z/
# sub folder :  wydot/BSM/20170815T234602071Z/
# sub folder :  wydot/BSM/20170815T234602076Z/
# sub folder :  wydot/BSM/20170815T234602083Z/
# sub folder :  wydot/BSM/20170815T234602111Z/
# sub folder :  wydot/BSM/20170815T234602121Z/
# sub folder :  wydot/BSM/20170815T234602126Z/
# sub folder :  wydot/BSM/20170815T234602143Z/
# sub folder :  wydot/BSM/20170815T234602145Z/
# sub folder :  wydot/BSM/20170815T234602168Z/
# sub folder :  wydot/BSM/20170815T234602179Z/
# sub folder :  wydot/BSM/20170815T234602187Z/
# sub folder :  wydot/BSM/20170815T234602199Z/
# sub folder :  wydot/BSM/20170815T2346021Z/
# sub folder :  wydot/BSM/20170815T234602203Z/
# sub folder :  wydot/BSM/20170815T234602215Z/
# sub folder :  wydot/BSM/20170815T23460222Z/
# sub folder :  wydot/BSM/20170815T234602257Z/
# sub folder :  wydot/BSM/20170815T234602278Z/
# sub folder :  wydot/BSM/20170815T234602293Z/
# sub folder :  wydot/BSM/20170815T234602311Z/
# sub folder :  wydot/BSM/20170815T234602348Z/
# sub folder :  wydot/BSM/20170815T23460234Z/
# sub folder :  wydot/BSM/20170815T234602358Z/
# sub folder :  wydot/BSM/20170815T234602372Z/
# sub folder :  wydot/BSM/20170815T234602403Z/
# sub folder :  wydot/BSM/20170815T234602413Z/
# sub folder :  wydot/BSM/20170815T234602427Z/
# sub folder :  wydot/BSM/20170815T234602431Z/
# sub folder :  wydot/BSM/20170815T234602437Z/
# sub folder :  wydot/BSM/20170815T234602445Z/
# sub folder :  wydot/BSM/20170815T234602449Z/
# sub folder :  wydot/BSM/20170815T234602455Z/
# sub folder :  wydot/BSM/20170815T234602465Z/
# sub folder :  wydot/BSM/20170815T234602469Z/
# sub folder :  wydot/BSM/20170815T234602482Z/
# sub folder :  wydot/BSM/20170815T234602485Z/
# sub folder :  wydot/BSM/20170815T234602507Z/
# sub folder :  wydot/BSM/20170815T234602513Z/
# sub folder :  wydot/BSM/20170815T234602518Z/
# sub folder :  wydot/BSM/20170815T234602524Z/
# sub folder :  wydot/BSM/20170815T234602532Z/
# sub folder :  wydot/BSM/20170815T234602542Z/
# sub folder :  wydot/BSM/20170815T234602568Z/
# sub folder :  wydot/BSM/20170815T23460256Z/
# sub folder :  wydot/BSM/20170815T234602606Z/
# sub folder :  wydot/BSM/20170815T234602612Z/
# sub folder :  wydot/BSM/20170815T234602619Z/
# sub folder :  wydot/BSM/20170815T234602639Z/
# sub folder :  wydot/BSM/20170815T234602642Z/
# sub folder :  wydot/BSM/20170815T23460264Z/
# sub folder :  wydot/BSM/20170815T234602652Z/
# sub folder :  wydot/BSM/20170815T234602661Z/
# sub folder :  wydot/BSM/20170815T23460266Z/
# sub folder :  wydot/BSM/20170815T234602683Z/
# sub folder :  wydot/BSM/20170815T234602685Z/
# sub folder :  wydot/BSM/20170815T23460268Z/
# sub folder :  wydot/BSM/20170815T2346026Z/
# sub folder :  wydot/BSM/20170815T234602713Z/
# sub folder :  wydot/BSM/20170815T234602721Z/
# sub folder :  wydot/BSM/20170815T234602722Z/
# sub folder :  wydot/BSM/20170815T234602724Z/
# sub folder :  wydot/BSM/20170815T234602731Z/
# sub folder :  wydot/BSM/20170815T234602736Z/
# sub folder :  wydot/BSM/20170815T234602738Z/
# sub folder :  wydot/BSM/20170815T234602761Z/
# sub folder :  wydot/BSM/20170815T234602762Z/
# sub folder :  wydot/BSM/20170815T23460278Z/
# sub folder :  wydot/BSM/20170815T234602794Z/
# sub folder :  wydot/BSM/20170815T234602795Z/
# sub folder :  wydot/BSM/20170815T2346027Z/
# sub folder :  wydot/BSM/20170815T234602803Z/
# sub folder :  wydot/BSM/20170815T234602804Z/
# sub folder :  wydot/BSM/20170815T234602805Z/
# sub folder :  wydot/BSM/20170815T234602806Z/
# sub folder :  wydot/BSM/20170815T234602808Z/
# sub folder :  wydot/BSM/20170815T234602809Z/
# sub folder :  wydot/BSM/20170815T234602811Z/
# sub folder :  wydot/BSM/20170815T234602817Z/
# sub folder :  wydot/BSM/20170815T234602826Z/
# sub folder :  wydot/BSM/20170815T234602829Z/
# sub folder :  wydot/BSM/20170815T23460283Z/
# sub folder :  wydot/BSM/20170815T234602846Z/
# sub folder :  wydot/BSM/20170815T234602862Z/
# sub folder :  wydot/BSM/20170815T234602864Z/
# sub folder :  wydot/BSM/20170815T234602866Z/
# sub folder :  wydot/BSM/20170815T234602868Z/
# sub folder :  wydot/BSM/20170815T23460286Z/
# sub folder :  wydot/BSM/20170815T234602875Z/
# sub folder :  wydot/BSM/20170815T234602901Z/
# sub folder :  wydot/BSM/20170815T234602915Z/
# sub folder :  wydot/BSM/20170815T234602918Z/
# sub folder :  wydot/BSM/20170815T234602941Z/
# sub folder :  wydot/BSM/20170815T234602942Z/
# sub folder :  wydot/BSM/20170815T23460294Z/
# sub folder :  wydot/BSM/20170815T234602952Z/
# sub folder :  wydot/BSM/20170815T234602953Z/
# sub folder :  wydot/BSM/20170815T234602954Z/
# sub folder :  wydot/BSM/20170815T234602965Z/
# sub folder :  wydot/BSM/20170815T234602966Z/
# sub folder :  wydot/BSM/20170815T234602969Z/
# sub folder :  wydot/BSM/20170815T234602993Z/
# sub folder :  wydot/BSM/20170815T234603013Z/
# sub folder :  wydot/BSM/20170815T234603026Z/
# sub folder :  wydot/BSM/20170815T234603028Z/
# sub folder :  wydot/BSM/20170815T234603033Z/
# sub folder :  wydot/BSM/20170815T23460304Z/
# sub folder :  wydot/BSM/20170815T23460305Z/
# sub folder :  wydot/BSM/20170815T234603066Z/
# sub folder :  wydot/BSM/20170815T234603067Z/
# sub folder :  wydot/BSM/20170815T234603073Z/
# sub folder :  wydot/BSM/20170815T234603076Z/
# sub folder :  wydot/BSM/20170815T234603077Z/
# sub folder :  wydot/BSM/20170815T234603084Z/
# sub folder :  wydot/BSM/20170815T234603085Z/
# sub folder :  wydot/BSM/20170815T234603086Z/
# sub folder :  wydot/BSM/20170815T234603101Z/
# sub folder :  wydot/BSM/20170815T234603103Z/
# sub folder :  wydot/BSM/20170815T234603112Z/
# sub folder :  wydot/BSM/20170815T234603128Z/
# sub folder :  wydot/BSM/20170815T234603137Z/
# sub folder :  wydot/BSM/20170815T234603138Z/
# sub folder :  wydot/BSM/20170815T234603146Z/
# sub folder :  wydot/BSM/20170815T234603155Z/
# sub folder :  wydot/BSM/20170815T234603163Z/
# sub folder :  wydot/BSM/20170815T234603168Z/
# sub folder :  wydot/BSM/20170815T234603174Z/
# sub folder :  wydot/BSM/20170815T234603179Z/
# sub folder :  wydot/BSM/20170815T234603193Z/
# sub folder :  wydot/BSM/20170815T234603197Z/
# sub folder :  wydot/BSM/20170815T234603201Z/
# sub folder :  wydot/BSM/20170815T234603205Z/
# sub folder :  wydot/BSM/20170815T234603215Z/
# sub folder :  wydot/BSM/20170815T234603235Z/
# sub folder :  wydot/BSM/20170815T23460323Z/
# sub folder :  wydot/BSM/20170815T234603242Z/
# sub folder :  wydot/BSM/20170815T234603259Z/
# sub folder :  wydot/BSM/20170815T234603273Z/
# sub folder :  wydot/BSM/20170815T234603278Z/
# sub folder :  wydot/BSM/20170815T234603281Z/
# sub folder :  wydot/BSM/20170815T234603284Z/
# sub folder :  wydot/BSM/20170815T234603286Z/
# sub folder :  wydot/BSM/20170815T234603294Z/
# sub folder :  wydot/BSM/20170815T234603298Z/
# sub folder :  wydot/BSM/20170815T234603311Z/
# sub folder :  wydot/BSM/20170815T234603316Z/
# sub folder :  wydot/BSM/20170815T234603319Z/
# sub folder :  wydot/BSM/20170815T234603321Z/
# sub folder :  wydot/BSM/20170815T234603322Z/
# sub folder :  wydot/BSM/20170815T234603335Z/
# sub folder :  wydot/BSM/20170815T234603338Z/
# sub folder :  wydot/BSM/20170815T23460333Z/
# sub folder :  wydot/BSM/20170815T234603343Z/
# sub folder :  wydot/BSM/20170815T234603344Z/
# sub folder :  wydot/BSM/20170815T234603345Z/
# sub folder :  wydot/BSM/20170815T234603358Z/
# sub folder :  wydot/BSM/20170815T234603359Z/
# sub folder :  wydot/BSM/20170815T234603369Z/
# sub folder :  wydot/BSM/20170815T23460336Z/
# sub folder :  wydot/BSM/20170815T234603373Z/
# sub folder :  wydot/BSM/20170815T234603374Z/
# sub folder :  wydot/BSM/20170815T234603375Z/
# sub folder :  wydot/BSM/20170815T234603376Z/
# sub folder :  wydot/BSM/20170815T234603377Z/
# sub folder :  wydot/BSM/20170815T234603378Z/
# sub folder :  wydot/BSM/20170815T234603379Z/
# sub folder :  wydot/BSM/20170815T23460337Z/
# sub folder :  wydot/BSM/20170815T234603382Z/
# sub folder :  wydot/BSM/20170815T234603383Z/
# sub folder :  wydot/BSM/20170815T234603387Z/
# sub folder :  wydot/BSM/20170815T234603389Z/
# sub folder :  wydot/BSM/20170815T23460338Z/
# sub folder :  wydot/BSM/20170815T234603392Z/
# sub folder :  wydot/BSM/20170815T234603393Z/
# sub folder :  wydot/BSM/20170815T234603395Z/
# sub folder :  wydot/BSM/20170815T234603396Z/
# sub folder :  wydot/BSM/20170815T234603397Z/
# sub folder :  wydot/BSM/20170815T234603399Z/
# sub folder :  wydot/BSM/20170815T234603401Z/
# sub folder :  wydot/BSM/20170815T234603403Z/
# sub folder :  wydot/BSM/20170815T234603404Z/
# sub folder :  wydot/BSM/20170815T234603405Z/
# sub folder :  wydot/BSM/20170815T234603406Z/
# sub folder :  wydot/BSM/20170815T234603407Z/
# sub folder :  wydot/BSM/20170815T234603408Z/
# sub folder :  wydot/BSM/20170815T234603409Z/
# sub folder :  wydot/BSM/20170815T234603414Z/
# sub folder :  wydot/BSM/20170815T234603416Z/
# sub folder :  wydot/BSM/20170815T234603417Z/
# sub folder :  wydot/BSM/20170815T234603454Z/
# sub folder :  wydot/BSM/20170815T234603484Z/
# sub folder :  wydot/BSM/20170815T234603486Z/
# sub folder :  wydot/BSM/20170815T234603493Z/
# sub folder :  wydot/BSM/20170815T234603496Z/
# sub folder :  wydot/BSM/20170815T2346034Z/
# sub folder :  wydot/BSM/20170815T234603506Z/
# sub folder :  wydot/BSM/20170815T234603509Z/
# sub folder :  wydot/BSM/20170815T234603511Z/
# sub folder :  wydot/BSM/20170815T234603512Z/
# sub folder :  wydot/BSM/20170815T234603515Z/
# sub folder :  wydot/BSM/20170815T234603517Z/
# sub folder :  wydot/BSM/20170815T234603519Z/
# sub folder :  wydot/BSM/20170815T234603521Z/
# sub folder :  wydot/BSM/20170815T234603522Z/
# sub folder :  wydot/BSM/20170815T234603524Z/
# sub folder :  wydot/BSM/20170815T234603525Z/
# sub folder :  wydot/BSM/20170815T234603526Z/
# sub folder :  wydot/BSM/20170815T234603529Z/
# sub folder :  wydot/BSM/20170815T23460352Z/
# sub folder :  wydot/BSM/20170815T234603533Z/
# sub folder :  wydot/BSM/20170815T234603535Z/
# sub folder :  wydot/BSM/20170815T234603538Z/
# sub folder :  wydot/BSM/20170815T234603543Z/
# sub folder :  wydot/BSM/20170815T234603545Z/
# sub folder :  wydot/BSM/20170815T234603546Z/
# sub folder :  wydot/BSM/20170815T23460354Z/
# sub folder :  wydot/BSM/20170815T234603559Z/
# sub folder :  wydot/BSM/20170815T234603561Z/
# sub folder :  wydot/BSM/20170815T234603566Z/
# sub folder :  wydot/BSM/20170815T234603568Z/
# sub folder :  wydot/BSM/20170815T234603595Z/
# sub folder :  wydot/BSM/20170815T234603609Z/
# sub folder :  wydot/BSM/20170815T234603617Z/
# sub folder :  wydot/BSM/20170815T234603619Z/
# sub folder :  wydot/BSM/20170815T234603629Z/
# sub folder :  wydot/BSM/20170815T234603631Z/
# sub folder :  wydot/BSM/20170815T234603637Z/
# sub folder :  wydot/BSM/20170815T234603639Z/
# sub folder :  wydot/BSM/20170815T234603647Z/
# sub folder :  wydot/BSM/20170815T234603824Z/
# sub folder :  wydot/BSM/20170815T234603835Z/
# sub folder :  wydot/BSM/20170815T234603837Z/
# sub folder :  wydot/BSM/20170815T234603841Z/
# sub folder :  wydot/BSM/20170815T234603844Z/
# sub folder :  wydot/BSM/20170815T234603848Z/
# sub folder :  wydot/BSM/20170815T234603852Z/
# sub folder :  wydot/BSM/20170815T234603857Z/
# sub folder :  wydot/BSM/20170815T234603867Z/
# sub folder :  wydot/BSM/20170815T234603873Z/
# sub folder :  wydot/BSM/20170815T234603876Z/
# sub folder :  wydot/BSM/20170815T234603878Z/
# sub folder :  wydot/BSM/20170815T234603879Z/
# sub folder :  wydot/BSM/20170815T234603882Z/
# sub folder :  wydot/BSM/20170815T234603897Z/
# sub folder :  wydot/BSM/20170815T234603903Z/
# sub folder :  wydot/BSM/20170815T234603907Z/
# sub folder :  wydot/BSM/20170815T234603909Z/

# %% [markdown]
# ### Function for pulling file keys from the ASW S3 bucket

# %%
def dir_keys(client, bucket, prefix='', filekeys=[]):
    """
    Lists all file keys from a given prefix in an S3 bucket.  If no prefix is given all file keys are returned

    :param client: S3 connection object
    :param bucket: Name of bucket to search
    :param prefix: Prefix for a given folder
    :param filekeys: list for filekeys
    :return: updated filekey list with added files from search
    """
    paginator = client.get_paginator('list_objects_v2')
    for result in paginator.paginate(Bucket=bucket, Delimiter='/', Prefix=prefix):
        if result.get('Contents') is not None:
            for file in result.get('Contents'):
                if file.get('Key') != 'unknownDataType':
                    filekeys.append(file.get('Key'))
        if result.get('CommonPrefixes') is not None:
            for subdir in result.get('CommonPrefixes'):
                dir_keys(client, bucket, subdir.get('Prefix'), filekeys)
    return filekeys

# %% [markdown]
# ### Pull all file key for Aug 14 2017 at 19:43 and determine the number of files

# %%
filekeys = dir_keys(client, 'usdot-its-cvpilot-public-data', 'wydot/BSM/20170814T1943')
print('Total number of files:', str(len(filekeys)))
# Out:
# Total number of files: 114

# %% [markdown]
# ### Download files to locate Directory to do analysis on

# %%
import os
cwd = os.getcwd()
local_directory = cwd + os.sep + 'tmp' + os.sep
if not os.path.exists(local_directory):
    os.makedirs(local_directory)
print('Directory Created: {}'.format(local_directory))
# Out:
# Directory Created: /Users/m28050/Projects/Current/RDE Enhancement/Tasks/Task4_New_System/Sandbox/notebooks/tmp/

# %% [markdown]
# ### Download files to local folder

# %%
for file in filekeys:
    client.download_file('usdot-its-cvpilot-public-data', file, local_directory + file.split('/')[-1])
print('{} Files loaded to {}'.format(str(len(os.listdir(local_directory))), local_directory))
# Out:
# 115 Files loaded to /Users/m28050/Projects/Current/RDE Enhancement/Tasks/Task4_New_System/Sandbox/notebooks/tmp/

# %% [markdown]
# ### Look at one of the JSON files

# %%
# !cat /tmp/wydot-filtered-bsm-1501782536777.json
# Out:
# {"coreData":{"msgCnt":109,"id":"D5960000","secMark":18000,"position":{"latitude":41.2970116,"longitude":-105.5945026,"elevation":2194.5},"accelSet":{"accelYaw":0.00},"accuracy":{},"speed":19.04,"heading":351.4500,"brakes":{"wheelBrakes":{"leftFront":false,"rightFront":false,"unavailable":true,"leftRear":false,"rightRear":false},"traction":"unavailable","abs":"unavailable","scs":"unavailable","brakeBoost":"unavailable","auxBrakes":"unavailable"},"size":{}},"partII":[{"id":"VEHICLESAFETYEXT","value":{"pathHistory":{"crumbData":[{"elevationOffset":-2.7,"latOffset":0.0014126,"lonOffset":-0.0002730,"timeOffset":7.80},{"elevationOffset":-11.1,"latOffset":0.0032465,"lonOffset":-0.0006066,"timeOffset":16.70}]},"pathPrediction":{"confidence":0.0,"radiusOfCurve":0.0}}}]}

# %% [markdown]
# ### Combine the JSON files into a single JSON file

# %%
import glob

read_files = glob.glob(local_directory + "*.json")
with open(local_directory + "merged_file.json", "w") as outfile:
    data = []
    for f in read_files:
        data.append(open(f, "r").read())
    outfile.write("[" + ','.join(data[1:]) + "]")

# %% [markdown]
# ### Load file into data structure and remove partII tag as that information will not be used in this analysis
# *Data is in J2735 format http://standards.sae.org/j2735_201603/*

# %%
from pandas.io.json import json_normalize
import json

file_json = json.load(open(local_directory + "merged_file.json","r"))

for element in file_json: 
    del element['partII'] 

result = json_normalize(file_json)
result.head()
# Out:
#    coreData.accelSet.accelLong  coreData.accelSet.accelYaw  \
# 0                          NaN                        0.00
# 1                        -0.03                        0.05
# 2                         0.01                        0.15
# 3                          NaN                        0.00
# 4                         0.15                        0.02
#
#   coreData.brakes.abs coreData.brakes.auxBrakes coreData.brakes.brakeBoost  \
# 0         unavailable               unavailable                unavailable
# 1         unavailable               unavailable                unavailable
# 2         unavailable               unavailable                unavailable
# 3         unavailable               unavailable                unavailable
# 4         unavailable               unavailable                unavailable
#
#   coreData.brakes.scs coreData.brakes.traction  \
# 0         unavailable              unavailable
# 1         unavailable              unavailable
# 2         unavailable              unavailable
# 3         unavailable              unavailable
# 4         unavailable              unavailable
#
#    coreData.brakes.wheelBrakes.leftFront  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    coreData.brakes.wheelBrakes.leftRear  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    coreData.brakes.wheelBrakes.rightFront  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    coreData.brakes.wheelBrakes.rightRear  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    coreData.brakes.wheelBrakes.unavailable  coreData.heading coreData.id  \
# 0                                     True          289.7250    16C50000
# 1                                     True          289.7000    16C50000
# 2                                     True          289.7750    16C50000
# 3                                     True          289.8500    16C50000
# 4                                     True          289.7875    16C50000
#
#    coreData.msgCnt  coreData.position.elevation  coreData.position.latitude  \
# 0               85                       2188.9                   41.300245
# 1               86                       2188.9                   41.300253
# 2               90                       2188.8                   41.300286
# 3               93                       2188.8                   41.300311
# 4               94                       2188.7                   41.300319
#
#    coreData.position.longitude  coreData.secMark  coreData.speed
# 0                  -105.604298             37600           27.24
# 1                  -105.604329             37700           27.24
# 2                  -105.604451             38100           27.26
# 3                  -105.604543             38400           27.28
# 4                  -105.604574             38500           27.32

# %% [markdown]
# ### Do some basic analysis on the speed

# %%
result['coreData.speed'].describe()
# Out:
# count    114.000000
# mean      26.838772
# std        4.330284
# min       21.060000
# 25%       22.895000
# 50%       26.130000
# 75%       29.910000
# max       34.540000
# Name: coreData.speed, dtype: float64
